# %% [markdown]
# # Saudi Arabia Used Cars
#
# -----

# %% [markdown]
# # Daftar Isi
#
# 1. Pemahaman Masalah Bisnis
# 2. Pemahaman Data
# 3. Analisis Eksplorasi Data (EDA)
# 4. Pra-Pemrosesan Data
# 5. *Modeling*
# 6. Kesimpulan dan Rekomendasi

# %% [markdown]
# # 1. Pemahaman Masalah Bisnis
#
# ## 1.1 Latar Belakang
#
# **syarah.com** merupakan sebuah aplikasi jual-beli mobil bekas bergaransi dan baru *online* yang melayani seluruh wilayah kerajaan Arab. Dengan penjualan tahunan yang mencapai puluhan ribu mobil serta ribuan pengguna yang merasa puas, aplikasi ini memberikan pengalaman pembelian dan penjualan *online* yang nyaman, mudah, serta dilengkapi layanan pengiriman mobil langsung ke depan pintu pelanggan. Aplikasi ini juga garansi menyeluruh selama satu tahun untuk mobil bekas, serta jaminan pengembalian dalam waktu 10 hari apabila mobil yang dibeli tidak memuaskan selama masa percobaan (*trial*) tanpa alasan apapun.
#
# Aplikasi ini ditujukan untuk dua segmen pelanggan: Pelanggan yang ingin menjual mobil bekas serta pelanggan yang ingin membeli mobil, baik bekas maupun baru.
#
# Bagi pelanggan yang ingin menjual mobil bekas, mereka diminta untuk melengkapi detail mobil, memasukkan perkiraan harga, dan mendaftar jadwal inspeksi mobil. Setelah inspeksi dilakukan, pihak aplikasi akan menentukan harga akhir yang sesuai dengan kondisi mobil.
#
# Sementara itu, bagi pelanggan yang ingin membeli mobil (baik bekas atau baru), mereka akan diminta untuk membayar uang muka (*Down Payment*) terlebih dahulu. Pembayaran awal ini bersifat *refundable* atau dapat dikembalikan jika pembelian dibatalkan pada saat tahap registrasi. Uang muka ini nantinya akan dikurangi dari total harga saat pembayaran proses registrasi.
#
# Keuntungan bagi pelanggan yang membeli mobil melalui aplikasi ini mencakup biaya pengiriman gratis serta garansi tambahan dalam jangka waktu tertentu atau hingga mencapai kilometer yang telah ditentukan, tergantung mana yang tercapai lebih dahulu.
#
# Sumber: [syarah.com](https://syarah.com/en/about-us)

# %% [markdown]
# ## 1.2 Rumusan Masalah
#
# Variasi harga mobil bekas dipengaruhi oleh berbagai faktor, seperti tahun produksi, jarak tempuh (kilometer penggunaan), kapasitas mesin, tipe transmisi, dan berbagai faktor lainnya. Penentuan harga yang tidak akurat dapat menurunkan efisiensi transaksi di aplikasi syarah.com. Hal ini dapat menyebakan penjual merasa dirugikan jika harga yang disarankan terlalu rendah atau pembeli dapat kehilangan kepercayaan jika harga terlalu tinggi tanpa alasan yang jelas. Saat ini, metode penentuan harga berbasis inspeksi manual memakan waktu dan beresiko menghasilkan estimasi yang tidak konsisten.

# %% [markdown]
# ## 1.3 Tujuan
#
# Berdasarkan permasalahan yang telah diidentifikasi, tujuan dari proyek ini adalah untuk membangun model prediktif yang dapat memperkirakan harga mobil bekas secara akurat, berdasarkan faktor-faktor seperti tahun produksi, jarak tempuh, kapasitas mesin, tipe transmisi, dan spesifikasi lainnya. Model ini diharapkan dapat:
#
# 1. **Mengurangi Ketidak-konsistenan Penentuan Harga**</br>
# Model ini bertujuan untuk mengurangi ketidakkonsistenan dalam penentuan harga mobil bekas yang seringkali dihasilkan melalui metode manual, yang dapat menimbulkan ketidakakuratan dan perbedaan harga yang signifikan.
#
# 2. **Meningkatkan Efisiensi Transaksi di Syarah.com**</br>
# Dengan memberikan estimasi harga yang lebih transparan, konsisten, dan dapat dipercaya, model ini diharapkan dapat mempercepat proses transaksi di platform syarah.com, sehingga lebih efisien baik bagi penjual maupun pembeli.
#
# 3. **Memberikan Referensi yang Andal untuk Pengambilan Keputusan**</br>
# Model ini bertujuan untuk memberikan referensi yang lebih andal bagi penjual dan pembeli dalam pengambilan keputusan jual beli mobil bekas. Dengan harga yang lebih akurat, keputusan transaksi dapat dilakukan dengan lebih percaya diri.
#
# 4. **Menjaga Profit Syarah.com dan Memenuhi Ekspektasi Penjual**</br>
# Dengan model yang dapat memperkirakan harga sesuai ekspektasi penjual, syarah.com dapat memastikan bahwa harga yang ditawarkan tidak terlalu rendah (sehingga mengurangi potensi kerugian bagi penjual), sekaligus menjaga profit yang diinginkan oleh platform.
#
# Secara keseluruhan, model ini diharapkan dapat memperbaiki proses transaksi di syarah.com, memastikan harga yang wajar dan sesuai ekspektasi, serta meningkatkan kepuasan dan kepercayaan pengguna terhadap platform, dengan stakeholder utama adalah penjual yang akan mendapatkan harga yang sesuai dan platform yang dapat menjaga margin keuntungan.

# %% [markdown]
# ## 1.4 Evaluasi Metrik
#
# Beberapa metrik evaluasi yang akan digunakan untuk menilai performa model adalah sebagai berikut:
# - **R-Squared (R²)**: Metrik ini wajib digunakan, karena memberikan indikasi seberapa baik model mampu menjelaskan variasi data yang ada. Nilai R² yang lebih tinggi menunjukkan model yang lebih baik dalam menjelaskan hubungan antara fitur dan target.
#
# - **MAE (Mean Absolute Error)**: Mengukur rata-rata selisih absolut antara prediksi dan nilai aktual. MAE memberikan gambaran seberapa besar kesalahan prediksi model dalam satuan yang sama dengan target (harga mobil bekas).
#
# - **RMSE (Root Mean Squared Error)**: RMSE memberikan gambaran lebih jelas mengenai dampak kesalahan yang lebih besar dalam prediksi. Metrik ini sensitif terhadap outlier, sehingga sangat berguna dalam evaluasi model yang berpotensi menghasilkan prediksi ekstrem.
#
# - **MAPE (Mean Absolute Percentage Error)**: Mengukur seberapa besar persentase kesalahan dalam prediksi model, memberikan perspektif yang lebih mudah dipahami dalam konteks nilai relatif.
#
# Dari metrik ini, R² akan menjadi metrik utama yang digunakan untuk mengevaluasi keberhasilan model, sementara metrik lainnya (MAE, MSE, RMSE, MAPE) digunakan untuk menggali lebih dalam seberapa besar dan konsisten kesalahan yang dihasilkan oleh model.

# %% [markdown]
# ## 1.5 Metode dan Alur Analisis Proyek
#
# Secara garis besar, proyek ini terbagi atas langkah-langkah berikut:
#
# 1. **Pemahaman Masalah**
#
# 2. **Pemahaman dan Persiapan Data**
#
# 3. **Modeling**
#
# 4. **Evaluasi dan Interpretasi Model**
#
# 5. **Kesimpulan dan Rekomendasi**

# %% [markdown]
# # 2. Pemahaman Data

# %% [markdown]
# Dataset ini berisi daftar mobil bekas yang dijual di Arab Saudi melalui aplikasi atau situs web Syarah.com. Terdapat **5624 baris** dan **11 kolom** yang merepresentasikan informasi rinci terkait mobil yang tersedia untuk dijual. Informasi mengenai atribut mobil yang relevan tersedia pada tabel dibawah ini:
#
# | **Kolom**          | **Deskripsi**                                                      |
# |---------------------|-------------------------------------------------------------------|
# | **Type**           | Jenis mobil bekas.                                               |
# | **Region**         | Wilayah tempat mobil bekas ditawarkan untuk dijual.              |
# | **Make**           | Nama perusahaan pembuat mobil.                                   |
# | **Gear_Type**      | Jenis transmisi mobil bekas.                                     |
# | **Origin**         | Asal mobil bekas.                                               |
# | **Options**        | Opsi tambahan yang tersedia pada mobil bekas.                   |
# | **Year**           | Tahun pembuatan mobil.                                          |
# | **Engine_Size**    | Ukuran mesin mobil bekas.                                       |
# | **Mileage**        | Jarak tempuh mobil bekas.                                        |
# | **Negotiable**     | Bernilai *True* jika harga 0, yang berarti harga dapat dinegosiasikan. |
# | **Price**          | Harga mobil bekas.                                              |                                            |

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import shap

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, KFold

import category_encoders as ce
import statsmodels.api as sm
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.kernel_ridge import KernelRidge
from scipy.stats import shapiro

from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import RobustScaler

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
randomstate = 42

# %% [markdown]
# ## 2.1 *Read Dataset*

# %%
df = pd.read_csv('data_saudi_used_cars.csv')
df
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 0         Corolla            Abha      Toyota     Manual        Saudi
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 4              FJ          Riyadh      Toyota  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5620       Altima          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
# 5623           ES          Jeddah       Lexus  Automatic        Other
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# ...

# %% [markdown]
# Berikut adalah informasi umum mengenai dataset yang memberikan gambaran dan memahami jenis data seperti jumlah kolom, tipe data di setiap kolom, jumlah nilai non-null, dan data unik di setiap kolom.

# %% [markdown]
# Berikut hasil analisis statistik deskriptif untuk kolom dengan tipe numerik (**Year**, **Engine_Size**, **Mileage**, dan **Price**), kategorik (**Type**, **Region**, **Make**, **Gear_Type**, dan **Options**), serta boolean (**Negotiable**).

# %%
display(df.info(), df.describe().round(2), df.describe(include=['object', 'bool']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624 entries, 0 to 5623
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         5624 non-null   object
#  1   Region       5624 non-null   object
#  2   Make         5624 non-null   object
#  3   Gear_Type    5624 non-null   object
#  4   Origin       5624 non-null   object
#  5   Options      5624 non-null   object
#  6   Year         5624 non-null   int64
#  7   Engine_Size  5624 non-null   float64
#  8   Mileage      5624 non-null   int64
#  9   Negotiable   5624 non-null   bool
#  10  Price        5624 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 445.0+ KB
# None
#           Year  Engine_Size      Mileage      Price
# count  5624.00      5624.00      5624.00    5624.00
# mean   2014.10         3.30    150923.38   53074.06
# std       5.79         1.52    382835.96   70155.34
# ...

# %% [markdown]
# # 3. Analisis Eksplorasi Data (EDA)

# %% [markdown]
# **Exploratory Data Analysis** atau **Analisis Eksplorasi Data** dilakukan untuk memahami karakteristik data, memahami pola atau hubungan sebelum masuk ke tahap analisis lebih lanjut atau pemodelan. Pada tahapan ini, proses EDA akan dibagi menjadi **Analisis Eksplorasi Data Numerik** dan **Analisis Eksplorasi Data Kategorikal**.
#
# Pada proyek analisis kali ini, variabel data terbagi menjadi variabel dependen atau target dan variabel independen atau fitur. Dari 10 kolom yang ada, kolom **Harga** atau **Price** merupakan Target sedangan sembilan kolom lainnya merupakan variabel independen atau **feature**. Pembagian fitur berdasarkan tipe data:
#
# - Variabel Numerik : Year, Engine_Size, Mileage, dan Price
# - Variabel Kategorikal : Type, Make, Region, Gear_Type, Origin, Options, dan Negotiable

# %% [markdown]
# ### 2.2.1 Analisis Variabel Numerik

# %% [markdown]
# **Visualisasi Histogram dan Box Plot**

# %%
num_data = df[['Year', 'Engine_Size', 'Mileage', 'Price']]

# Menentukan ukuran subplot mendatar (1 baris, 4 kolom)
num_cols = 4
num_rows = 1

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))
for i, col in enumerate(num_data.columns):
    sns.histplot(data=num_data[col], kde=True, bins=20, ax=axes[i])
    axes[i].set_title(f'Histogram of {col}', fontsize=10)
    axes[i].set_xlabel(col, fontsize=8)
    axes[i].set_ylabel('Frequency', fontsize=8)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

# Membuat boxplot untuk setiap kolom numerik
for i, col in enumerate(num_data.columns):
    sns.boxplot(data=num_data[col], ax=axes[i], orient='h')
    axes[i].set_title(f'Boxplot of {col}', fontsize=10)
    axes[i].set_xlabel(col, fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Analisis Statistik Deskriptif**

# %%
df.describe().T
# Out:
#               count           mean            std     min      25%       50%  \
# Year         5624.0    2014.101885       5.791606  1963.0   2012.0    2016.0
# Engine_Size  5624.0       3.295430       1.515108     1.0      2.0       3.0
# Mileage      5624.0  150923.375000  382835.963005   100.0  38000.0  103000.0
# Price        5624.0   53074.058144   70155.340614     0.0      0.0   36500.0
#
#                   75%         max
# Year           2018.0      2022.0
# Engine_Size       4.5         9.0
# Mileage      196000.0  20000000.0
# Price         72932.5    850000.0

# %% [markdown]
# Berdasarkan visualisasi dan tabel di atas, dapat diketahui bahwa:
#
# **Distribusi Kolom**
#
# 1. Visualisasi histogram menunjukkan bahwa kolom Engine_Size, Mileage, dan Price memiliki distribusi yang miring ke kanan (right/positive skewed), yang berarti sebagian besar nilai berada di sisi yang lebih kecil, dengan sedikit nilai ekstrim di sisi yang lebih besar;
# 2. Year memiliki distribusi yang miring ke kiri (left/negative skewed), yang berarti sebagian besar nilai berada di sisi yang lebih besar, dengan sedikit nilai ekstrim di sisi yang lebih kecil.
#
# **Outlier**
#
# Ditemukan adanya outlier pada masing-masing kolom. Outlier terlihat paling signifikan pada kolom Mileage, yang dapat memengaruhi analisis lebih lanjut.
#
# **Statistik Deskriptif**
#
# Berdasarkan tabel statistik deskriptif pada masing-masing kolom, dapat diketahui bahwa:
# - Mean dan median pada kolom Engine_Size, Mileage, dan Price tidak seimbang (terlihat dari skewness), yang menunjukkan adanya ketidaksimetrisan distribusi.
# - Kolom Year memiliki distribusi yang cenderung lebih terfokus pada nilai yang lebih besar, sesuai dengan distribusinya yang miring ke kiri.
# - Rentang (Range) pada kolom Mileage sangat luas, yang memperkuat indikasi adanya outlier signifikan.

# %% [markdown]
# ### 2.2.2 Analisis Variabel Kategorikal
#
# **Count Plot untuk Kolom Type, Make, dan Region**

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 15), sharex=False)

# Plot untuk kolom 'Type'
sns.countplot(
    x=df['Type'], 
    order=df['Type'].value_counts().head(15).index, 
    ax=axes[0], 
    palette='Paired'
)
axes[0].set_title('Distribusi Type (Top 15)', fontsize=12)
axes[0].set_xlabel('Type', fontsize=12)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].tick_params(axis='x', rotation=30)

# Plot untuk kolom 'Make'
sns.countplot(
    x=df['Make'], 
    order=df['Make'].value_counts().head(15).index,  
    ax=axes[1], 
    palette='Paired'
)
axes[1].set_title('Distribusi Make (Top 15)', fontsize=12)
axes[1].set_xlabel('Make', fontsize=12)
axes[1].set_ylabel('Count', fontsize=12)
axes[1].tick_params(axis='x', rotation=30)

# Plot untuk kolom 'Region'
sns.countplot(
    x=df['Region'], 
    order=df['Region'].value_counts().head(15).index,  
    ax=axes[2], 
    palette='Paired'
)
axes[2].set_title('Distribusi Region (Top 15)', fontsize=12)
axes[2].set_xlabel('Region', fontsize=12)
axes[2].set_ylabel('Count', fontsize=12)
axes[2].tick_params(axis='x', rotation=30)

# Menyelaraskan layout agar tidak ada overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan hasil Count Plot diatas, dapat diketahui bahwa:
#
# 1. Terdapat lebih dari 2.000 mobil dengan tipe/jenis Land Rover yang dijual di website Syarah.com. Jenis mobil ini menjadi yang paling banyak dijual, diikuti oleh Camry dan Hilux;
# 2. Toyota adalah merek mobil yang paling banyak dijual di website Syarah.com, diikuti oleh Hyundai dan Ford;
# 3. Riyadh merupakan lokasi dengan jumlah penjualan mobil bekas terbanyak di Arab Saudi dibandingkan dengan lokasi lain.

# %% [markdown]
# **Visualisasi Pie Chart untuk Kolom Gear_Type, Origin, Options, dan Negotiable**

# %%
columns = ['Gear_Type', 'Origin', 'Options', 'Negotiable']

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Loop melalui setiap kolom dan subplot
for col, ax in zip(columns, axes.flatten()):
    # Menghitung frekuensi
    data = df[col].value_counts()
    # Membuat pie chart
    ax.pie(
        data, 
        labels=data.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=plt.cm.Paired.colors
    )
    ax.set_title(f'Distribusi {col}', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan Pie Chart diatas, dapat diketahui bahwa:
#
# 1. Sebanyak 86.7% mobil yang dijual di website Syarah.com menggunakan transmisi automatic;
# 2. Sebanyak 74.5% mobil yang dijual di website Syarah.com berasal dari Saudi Arabia, diikuti oleh negara-negara di Gulf Arab, dan kategori Other. Untuk menangani kategori Unknown, variabel ini akan dikategorikan sebagai Others;
# 3. Kolom negotiable berhubungan dengan kolom Price. Jika harga mobil bekas sebesar 0 SAR, maka harga tersebut dapat dinegosiasikan, dan sebaliknya. Berdasarkan Pie Chart di atas, dapat diketahui bahwa 68.1% harga mobil bekas tidak dapat dinegosiasikan. Oleh karena itu, kolom ini akan dihapus pada saat Data Cleaning.

# %% [markdown]
# ### 2.2.3 Analisis Korelasi

# %% [markdown]
# **Analisis Korelasi Antar Kolom Numerik**

# %%
numeric_df =df.select_dtypes(include=[np.number])

# Anda dapat mengonversi nilai non-numerik menjadi NaN dan menghapusnya jika perlu
numeric = numeric_df.apply(pd.to_numeric, errors='coerce')

# Sekarang tampilkan matriks korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(numeric.corr('spearman'), annot=True, cmap='coolwarm')
plt.title("Matriks Korelasi", size=12)
plt.show()

# %% [markdown]
# Berdasarkan matriks korelasi diatas, dapat diketahui:
#
# 1. Terdapat korelasi positif antara Year dan Price sebesar 0.36. Ini menunjukkan bahwa semakin baru tahun mobil, harganya juga cenderung semakin tinggi;
# 2. Terdapat korelasi negatif yang lemah antara Price dan Mileage. Hal tersebut menunjukkan, semakin besar Mileage, maka harganya cenderung semakin turun;
# 3. Terdapat korelasi negatif antara Year dan Mileage sebesar -0.42. Ini menunjukkan semakin baru tahun mobil, jarak tempuhnya semakin rendah, begitu pula sebaliknya.

# %% [markdown]
# **Analisis Korelasi Kolom Price dan Kolom Kategorikal**

# %%
def correlation_ratio(categories, values):
    values = np.array(values)
    categories = np.array(categories)
    unique_categories = np.unique(categories)
    category_means = [values[categories == cat].mean() for cat in unique_categories]
    overall_mean = values.mean()
    ss_between = sum(
        len(values[categories == cat]) * (mean - overall_mean) ** 2
        for cat, mean in zip(unique_categories, category_means)
    )
    ss_total = sum((values - overall_mean) ** 2)
    return np.sqrt(ss_between / ss_total)

# %%
objects = df.select_dtypes(include=['object']).columns

# Menyimpan nilai korelasi
features = []

# Menghitung correlation ratio untuk setiap kolom kategorikal
for col in objects:
    corr = round(correlation_ratio(df[col], df['Price']), 2)
    features.append(corr)

# Membuat DataFrame hasil
df_ratio = pd.DataFrame(
    data=[features], 
    columns=list(objects), 
    index=['Price']
)

# Menampilkan heatmap
plt.figure(figsize=(10, 2))
sns.heatmap(df_ratio, annot=True, cbar=False, cmap='coolwarm')
plt.title('Correlation Ratio of Categorical Features with Price')
plt.show()

# %% [markdown]
# Berdasarkan hasil korelasi antara kolom katgeorikal dan Price diatas, dapat diketahui bahwa Type dan Make mobil bekas mempengaruhi Harga jual mobil di Syarah.com

# %% [markdown]
# # 4. Pra-Pemrosesan Data

# %% [markdown]
# ## 4.1 *Data Cleaning*

# %% [markdown]
# Proses data cleaning dilakukan untuk menyiapkan data yang akan di analisis. Teradapat empat tahapan yang akan dilakukan pada proses data cleaning:
#
# - Drop Kolom Fitur yang sekiranya tidak relevan dengan target;
# - Penanganan data duplikat untuk mencegah redundansi;
# - Penanganan Missing value yang bisa dilakukan dengan dua cara:
#     - Imputasi dengan nilai yang sesuai dengan kasus, atau
#     - Drop baris jika tidak dibutuhkan.
# - Penanganan data numerik, seperti:
#     - Binning;
#     - Penanganan outlier;
#     - Penghapusan data yang dinilai tidak sesuai dengan domain knowledge yang dimiliki.

# %% [markdown]
# Untuk mempermudah proses Cleaning, maka dilakukan penyalinan data asli:

# %%
saudi = df.copy()

# %% [markdown]
# Selanjutnya, proses Data Cleaning akan menggunakan variabel saudi.

# %% [markdown]
# ### 4.1.1 *Drop* Kolom

# %%
saudi = saudi.drop(saudi[saudi['Price'] == 0].index)
saudi.drop('Negotiable', axis = 1, inplace=True)

# %% [markdown]
# **Argumentasi**
#
# Penghapusan kolom **Negotiable** dan data dengan **Price == 0** dilakukan karena kedua informasi tersebut tidak relevan untuk prediksi harga. Nilai 0 pada kolom harga menunjukkan bahwa harga belum ditentukan atau masih dapat dinegosiasikan antara penjual dan pembeli (Negotiable).

# %% [markdown]
# ### 4.1.2 Penanganan Data Duplikat

# %%
saudi[saudi.duplicated()]
# Out:
#         Type  Region     Make  Gear_Type Origin   Options  Year  Engine_Size  \
# 953      Rio  Riyadh      Kia  Automatic  Saudi  Standard  2016          1.4
# 4646  Sonata  Jeddah  Hyundai  Automatic  Saudi  Standard  2020          2.4
# 4933  Tucson  Dammam  Hyundai  Automatic  Saudi  Standard  2016          2.0
#
#       Mileage  Price
# 953    270000  25000
# 4646      100  72910
# 4933   155000  45000

# %% [markdown]
# **Argumentasi**
#
# Penghapusan tiga baris duplikat dilakukan untuk menghindari data yang berulang (redundan), sehingga dataset menjadi lebih akurat dan tidak bias dalam analisis.

# %%
saudi.drop_duplicates(inplace=True)
saudi[saudi.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Type, Region, Make, Gear_Type, Origin, Options, Year, Engine_Size, Mileage, Price]
# Index: []

# %% [markdown]
# ### 4.1.3 Penanganan *Missing Values*

# %% [markdown]
# Berdasarkan informasi yang telah dilampirkan sebelumnya, dapat diketahui bahwa tidak terdapat baris kosong pada dataset ini. Namun, untuk memastikan bahwa data yang ada benar-benar bersih dan konsisten, dilakukan pembersihan lebih lanjut terhadap nilai-nilai yang tidak valid atau tidak relevan.
#
# Pada tahap ini, kode berikut digunakan untuk mengganti nilai-nilai yang dianggap tidak valid (seperti tanda tanya ?, NaN, Null, Unknown, -1, dan 9999) dengan nilai NaN (Not a Number), yang lebih tepat untuk penanganan data hilang:

# %%
saudi.replace(['?', 'NaN', 'Null', 'Unknown', '-1', '9999'], np.nan, inplace=True)

saudi.isna().sum()
# Out:
# Type            0
# Region          0
# Make            0
# Gear_Type       0
# Origin         16
# Options         0
# Year            0
# Engine_Size     0
# Mileage         0
# Price           0
# dtype: int64

# %%
missing_values = saudi[saudi['Origin'].isna()]
missing_values.head()
# Out:
#                Type     Region     Make  Gear_Type Origin   Options  Year  \
# 276         Charger     Riyadh    Dodge  Automatic    NaN      Full  2020
# 665   Grand Marquis  Al-Medina  Mercury  Automatic    NaN      Full  2007
# 800           Camry     Qassim   Toyota  Automatic    NaN      Full  2005
# 1174          Camry       Abha   Toyota  Automatic    NaN  Standard  2017
# 1376             ES     Jeddah    Lexus  Automatic    NaN      Full  2021
#
#       Engine_Size  Mileage   Price
# 276           3.6     9120  115000
# 665           4.6   179000   24000
# 800           2.5   437000   13000
# 1174          2.5   120000   59000
# 1376          3.5     1300  175000

# %% [markdown]
# Terdapat 16 Baris *Missing Values* pada kolom Origin. Untuk mengatasi hal tersebut, data dengan missing value akan diimputasi berdasarkan variabel yang paling sering muncul pada kolom Origin.

# %%
saudi['Origin'].fillna(saudi['Origin'].mode()[0], inplace=True)

# %%
filled_origin = saudi.loc[missing_values.index]
filled_origin = filled_origin[filled_origin['Origin'].notna()]
filled_origin
# Out:
#                Type     Region       Make  Gear_Type Origin    Options  Year  \
# 276         Charger     Riyadh      Dodge  Automatic  Saudi       Full  2020
# 665   Grand Marquis  Al-Medina    Mercury  Automatic  Saudi       Full  2007
# 800           Camry     Qassim     Toyota  Automatic  Saudi       Full  2005
# 1174          Camry       Abha     Toyota  Automatic  Saudi   Standard  2017
# 1376             ES     Jeddah      Lexus  Automatic  Saudi       Full  2021
# 1392          Focus     Jeddah       Ford  Automatic  Saudi   Standard  2011
# 1989          Camry  Al-Medina     Toyota  Automatic  Saudi       Full  2020
# 2147          Tahoe    Al-Ahsa  Chevrolet  Automatic  Saudi  Semi Full  2008
# 2613         Optima     Tabouk        Kia  Automatic  Saudi  Semi Full  2018
# 3209      Furniture    Al-Ahsa     Toyota  Automatic  Saudi  Semi Full  2017
# 3236          Camry     Riyadh     Toyota  Automatic  Saudi   Standard  2010
# ...

# %% [markdown]
# ### 4.1.4 Penanganan Data Numerik

# %%
# Memilih kolom-kolom numerik
num_data = saudi[['Year', 'Engine_Size', 'Mileage', 'Price']]

# Menentukan ukuran subplot mendatar (1 baris, 4 kolom)
num_cols = 4
num_rows = 1

# Membuat subplot mendatar
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

# Membuat histogram untuk setiap kolom numerik
for i, col in enumerate(num_data.columns):
    sns.histplot(data=num_data[col], kde=True, bins=20, ax=axes[i])
    axes[i].set_title(f'Histogram of {col}', fontsize=10)
    axes[i].set_xlabel(col, fontsize=8)
    axes[i].set_ylabel('Frequency', fontsize=8)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5))

# Membuat boxplot untuk setiap kolom numerik
for i, col in enumerate(num_data.columns):
    sns.boxplot(data=num_data[col], ax=axes[i], orient='h')
    axes[i].set_title(f'Boxplot of {col}', fontsize=10)
    axes[i].set_xlabel(col, fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.1.4.1 Penanganan pada Kolom Year

# %% [markdown]
# Pasar otomotif di Saudi Arabia cenderung menyukai kendaraan baru atau model terbaru dengan beberapa pertimbangan, seperti iklim, efisiensi bahan bakar, penggunaan harian intensif serta regulasi mengenai standar emisi. Berdasarkan hal tersebut, Mobil bekas yang diproduksi kurang dari tahun 2000 akan dihapus.

# %%
total_cars = len(saudi)
below_2000 = len(saudi[saudi['Year'] < 2000])
percentage_below_2000 = (below_2000 / total_cars) * 100

print(f"Mobil dengan tahun < 2000: {below_2000} ({percentage_below_2000:.2f}% dari total data)")
# Out:
# Mobil dengan tahun < 2000: 74 (1.94% dari total data)

# %%
saudi = saudi[saudi['Year'] >= 2000].reset_index(drop=True)

# %%
saudi
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 0           Yukon          Riyadh         GMC  Automatic        Saudi
# 1     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 2          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 3             CX3            Abha       Mazda  Automatic        Saudi
# 4       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 3745          CX9          Qassim       Mazda  Automatic        Saudi
# 3746     Suburban          Riyadh         GMC  Automatic        Saudi
# 3747      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 3748        Yukon          Dammam         GMC  Automatic        Saudi
# 3749           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage   Price
# 0          Full  2014          8.0    80000  120000
# ...

# %% [markdown]
# #### 4.1.4.2 Penanganan Outlier pada Kolom Mileage

# %%
saudi['Mileage'].describe().round(2)
# Out:
# count        3750.00
# mean       139819.01
# std        370840.95
# min           100.00
# 25%         49000.00
# 50%        103000.00
# 75%        181000.00
# max      20000000.00
# Name: Mileage, dtype: float64

# %% [markdown]
# Terdapat rentang nilai Mileage yang sangat lebar, yaitu dari 100 hingga 20,000,000. Nilai maksimum yang mencapai 20,000,000 sangat tidak wajar dan jauh lebih tinggi dibandingkan dengan nilai lainnya. Hal ini menunjukkan adanya outlier yang signifikan, yang bisa mempengaruhi analisis atau model yang akan digunakan. Untuk menangani hal tersebut, nilai yang dianggap terlalu jauh dan tidak wajar akan dihapus berdasarkan nilai Upperbound yang telah dihitung berdasarkan rumus berikut:

# %%
q1 = saudi['Mileage'].quantile(0.25)
q3 = saudi['Mileage'].quantile(0.75)
iqr = q3 - q1
limit = iqr * 1.5

lowerbound = q1 - limit
upperbound = q3 + limit

print('IQR =', iqr)
print('Batas Bawah =', lowerbound)
print('Batas Atas =', upperbound)
# Out:
# IQR = 132000.0
# Batas Bawah = -149000.0
# Batas Atas = 379000.0

# %% [markdown]
# **Interpretasi**
#
# 1. Nilai **IQR = 132000** menunjukkan nilai mileage antara mobil dengan mileage sedang dan tinggi;
# 2. Nilai **-149000** menunjukkan tidak ada nilai yang lebih kecil dari 0 dan akan dianggap sebagai outlier jika benar-benar ada;
# 3. Nilai di atas **379,000** dianggap sebagai mileage yang terlalu tinggi dibandingkan mayoritas data.

# %%
count_of_cars = saudi[saudi['Mileage'] > 379000].count()['Mileage']

print('Jumlah mobil dengan Mileage lebih dari 379000 sebanyak',count_of_cars, 'mobil')
# Out:
# Jumlah mobil dengan Mileage lebih dari 379000 sebanyak 129 mobil

# %% [markdown]
# Berdasarkan *domain knowledge* dan data yang terlampir di **syarah.com**, mobil dengan mileage lebih dari 300,000 terbilang jarang. Oleh karena itu, mobil dengan Mileage lebih dari batas atas (upper bound) yang sudah ditentukan sebelumnya akan di hapus agar hasil analisis yang dihasilkan menjadi lebih akurat dan representatif.

# %%
saudi = saudi[saudi['Mileage'] < 379000].reset_index(drop=True)

# %% [markdown]
# Pada dataset mobil yang tersedia, terdapat beberapa kendaraan dengan kilometer yang sangat rendah, terutama untuk mobil dengan jarak tempuh di bawah 22.000 kilometer. Berdasarkan data, beberapa mobil yang terdaftar memiliki kilometer yang jauh lebih rendah, bahkan di bawah 10.000 kilometer, yang tidak biasa mengingat bahwa rata-rata Vehicle Kilometers Traveled (VKT) di Arab Saudi pada tahun 2013 adalah sekitar 22.000 kilometer.

# %%
saudi[saudi['Mileage'] < 22000].sort_values(by='Mileage')
# Out:
#             Type  Region        Make  Gear_Type       Origin    Options  Year  \
# 2000    Defender  Jeddah  Land Rover  Automatic        Saudi       Full  2021
# 822        Delta   Aseer    Daihatsu     Manual        Saudi       Full  2014
# 3228      Sonata  Jeddah     Hyundai  Automatic        Saudi   Standard  2020
# 2741         CT4  Jeddah    Cadillac  Automatic  Gulf Arabic  Semi Full  2020
# 724          CT5  Jeddah    Cadillac  Automatic  Gulf Arabic  Semi Full  2021
# ...          ...     ...         ...        ...          ...        ...   ...
# 980     Victoria  Riyadh        Ford  Automatic        Saudi   Standard  2008
# 571        Hilux  Riyadh      Toyota  Automatic  Gulf Arabic  Semi Full  2014
# 1319         CX9  Riyadh       Mazda  Automatic        Saudi       Full  2020
# 3189   Furniture  Riyadh      Toyota  Automatic        Saudi   Standard  2020
# 1403  Expedition  Dammam        Ford  Automatic        Saudi   Standard  2013
#
# ...

# %%
saudi = saudi[saudi['Mileage'] > 22000].reset_index(drop=True)

# %% [markdown]
# Perbandingan Histogram sebelum dan sesudah proses Penanganan Outlier pada Kolom Mileage dapat dilihat pada viasualisasi berikut:

# %%
# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(df['Mileage'], ax=axes[0])
sns.distplot(saudi['Mileage'], ax=axes[1])
axes[0].set_xlabel('Mileage')
axes[1].set_xlabel('Range Selected Price');

# %%
# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.boxplot(df['Mileage'], ax=axes[0])
sns.boxplot(saudi['Mileage'], ax=axes[1])
axes[0].set_xlabel('Mileage')
axes[1].set_xlabel('Mileage');

# %% [markdown]
# #### 4.1.4.3 *Data Cleaning* pada Kolom Price

# %%
saudi.sort_values(by='Price', ascending=True)
# Out:
#              Type  Region         Make  Gear_Type       Origin    Options  \
# 1702        Yukon  Jubail          GMC  Automatic        Saudi       Full
# 2153          G80  Riyadh      Genesis  Automatic        Other  Semi Full
# 2378        Yaris  Riyadh       Toyota  Automatic        Saudi   Standard
# 2752          Rio    Arar          Kia  Automatic        Saudi   Standard
# 1881        Yaris  Najran       Toyota  Automatic        Saudi   Standard
# ...           ...     ...          ...        ...          ...        ...
# 1560  Range Rover  Riyadh   Land Rover  Automatic        Saudi       Full
# 1690  Range Rover  Riyadh   Land Rover  Automatic  Gulf Arabic       Full
# 1929  Range Rover  Riyadh   Land Rover  Automatic        Saudi       Full
# 1142        Ghost  Dammam  Rolls-Royce  Automatic        Saudi       Full
# 2521            G  Riyadh     Mercedes  Automatic        Other       Full
#
#       Year  Engine_Size  Mileage   Price
# ...

# %%
# Mendapatkan nilai kuartil dan limit
q1 = saudi['Price'].quantile(0.25)
q3 = saudi['Price'].quantile(0.75)
iqr = q3 - q1
limit = iqr * 1.5

lowerbound = q1 - limit
upperbound = q3 + limit

print('IQR =', iqr)
print('Batas Bawah =', lowerbound)
print('Batas Atas =', upperbound)
# Out:
# IQR = 55500.0
# Batas Bawah = -45750.0
# Batas Atas = 176250.0

# %% [markdown]
# Harga terendah yang tertera pada website **syarah.com** sebesar 22,000 SAR. Oleh karena itu, mobil dengan harga kurang dari 22,000 SAR akan di hapus agar hasil analisis lebih akurat dan representatif.

# %%
count_of_cars = saudi[(saudi['Price'] < 22000) | (saudi['Price'] > upperbound)].count()['Price']

print('Jumlah mobil dengan Price kurang dari 22000 dan lebih dari',upperbound,'sebanyak', count_of_cars, 'mobil')
# Out:
# Jumlah mobil dengan Price kurang dari 22000 dan lebih dari 176250.0 sebanyak 423 mobil

# %%
saudi.drop(saudi[(saudi['Price'] < 22000) | (saudi['Price'] > upperbound)].index, inplace=True)

# %%
# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(df['Price'], ax=axes[0])
sns.distplot(saudi['Price'], ax=axes[1])
axes[0].set_xlabel('Price')
axes[1].set_xlabel('Range Selected Price');

# %%
# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.boxplot(df['Price'], ax=axes[0])
sns.boxplot(saudi['Price'], ax=axes[1])
axes[0].set_xlabel('Price')
axes[1].set_xlabel('Range Selected Price');

# %% [markdown]
# ### 4.1.5 Dataset Akhir

# %%
saudi.reset_index(drop=True, inplace=True)

saudi
# Out:
#            Type          Region     Make  Gear_Type       Origin    Options  \
# 0         Yukon          Riyadh      GMC  Automatic        Saudi       Full
# 1        Optima  Hafar Al-Batin      Kia  Automatic        Saudi  Semi Full
# 2           CX3            Abha    Mazda  Automatic        Saudi  Semi Full
# 3     Cayenne S          Riyadh  Porsche  Automatic        Saudi       Full
# 4        Avalon          Riyadh   Toyota  Automatic        Saudi   Standard
# ...         ...             ...      ...        ...          ...        ...
# 2593          6          Jeddah    Mazda  Automatic        Saudi  Semi Full
# 2594   Suburban          Riyadh      GMC  Automatic        Saudi       Full
# 2595    X-Trail          Jeddah   Nissan  Automatic        Saudi   Standard
# 2596      Yukon          Dammam      GMC  Automatic        Saudi       Full
# 2597         RX          Dammam    Lexus  Automatic  Gulf Arabic       Full
#
#       Year  Engine_Size  Mileage   Price
# ...

# %%
display(saudi.isna().sum(), saudi.info(), saudi.describe(), saudi.describe(include=object))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         2598 non-null   object
#  1   Region       2598 non-null   object
#  2   Make         2598 non-null   object
#  3   Gear_Type    2598 non-null   object
#  4   Origin       2598 non-null   object
#  5   Options      2598 non-null   object
#  6   Year         2598 non-null   int64
#  7   Engine_Size  2598 non-null   float64
#  8   Mileage      2598 non-null   int64
#  9   Price        2598 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 203.1+ KB
# Type           0
# Region         0
# Make           0
# Gear_Type      0
# Origin         0
# Options        0
# Year           0
# Engine_Size    0
# Mileage        0
# Price          0
# dtype: int64
# None
#               Year  Engine_Size        Mileage          Price
# ...

# %% [markdown]
# Terdapat 2598 baris dan 10 kolom setelah proses data cleaning. Sebanyak 53,84% data dihapus karena tidak memenuhi kriteria analisis, seperti duplikasi serta data yang dianggap tidak relevan. Dataset yang telah dibersihkan ini akan menjadi dasar untuk proses analisis berikutnya dengan harapan menghasilkan insight yang lebih valid dan dapat diandalkan.

# %% [markdown]
# ## 4.2 Scaling dan Encoding

# %% [markdown]
# Metode yang digunakan pada proses encoding ini yaitu One Hot Encoder serta Binary Encoder sedangkan metode yang digunakan untuk scaling yaitu Robust Scaler.
#
# Adapun feature yang akan ditransformasi saat encoding yaitu:
#
# - One Hot Encoder : Gear_Type, Origin, dan Options
# - Binary Encoder : Type, Make, dan Region

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first'), ['Gear_Type', 'Origin', 'Options']),
    ('Binary', ce.BinaryEncoder(), ['Type','Make', 'Region'])
], remainder='passthrough')

scaler = RobustScaler()

# %% [markdown]
# # 5. Modeling

# %% [markdown]
# ## 5.1 Train-Test Split

# %% [markdown]
# **Train-Test Split** adalah proses membagi dataset menjadi dua bagian utama: train set dan test set. Tujuannya adalah untuk mempersiapkan data agar dapat digunakan untuk melatih dan menguji model machine learning dengan cara yang adil dan efektif.
#
# Dalam proses pembagian dataset, X merepresentasikan fitur-fitur seperti Year, Mileage, Region, dan fitur lainnya sedangkan y adalah variabel target yaitu Price. Dataset dibagi menggunakan fungsi train_test_split dengan rasio 80:20, di mana 80% data digunakan sebagai train set untuk melatih model mempelajari pola dari X untuk memprediksi y, sedangkan 20% data digunakan sebagai test set untuk menguji kemampuan generalisasi model.

# %%
X = saudi.drop(columns=['Price'])
y = saudi['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = randomstate)

print(X_train.shape,y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2078, 9) (2078,)
# (520, 9) (520,)

# %%
X_train
# Out:
#             Type   Region        Make  Gear_Type       Origin    Options  \
# 2174      Accent   Riyadh     Hyundai  Automatic        Saudi   Standard
# 931       Accent  Al-Jouf     Hyundai  Automatic        Saudi  Semi Full
# 841       Pajero   Khobar  Mitsubishi  Automatic        Saudi   Standard
# 1036      Sierra   Dammam         GMC  Automatic        Saudi   Standard
# 25        Previa   Riyadh      Toyota  Automatic  Gulf Arabic       Full
# ...          ...      ...         ...        ...          ...        ...
# 1638           C   Dammam    Mercedes  Automatic        Other       Full
# 1095  Expedition   Riyadh        Ford  Automatic        Saudi  Semi Full
# 1130         Rio   Riyadh         Kia  Automatic        Saudi   Standard
# 1294           6   Qassim       Mazda  Automatic        Saudi  Semi Full
# 860       Accent   Riyadh     Hyundai  Automatic        Saudi   Standard
#
#       Year  Engine_Size  Mileage
# 2174  2020          1.4    35547
# ...

# %% [markdown]
# Pada tahap ini, dilakukan **Feature Selection** menggunakan **metode Variance Inflation Factor (VIF)** untuk mengidentifikasi dan menghapus fitur-fitur yang memiliki multikolinearitas tinggi. Proses ini bertujuan untuk memastikan bahwa hanya fitur yang independen satu sama lain yang digunakan dalam pelatihan model, sehingga meningkatkan interpretabilitas dan performa model.
#
# Untuk meminimalisir data leakage, penghitungan VIF hanya dilakukan pada training set yang telah dipisahkan sebelumnya. Dengan cara ini, informasi dari test set tidak memengaruhi proses pemilihan fitur. Setelah fitur dengan VIF tinggi dihapus berdasarkan analisis pada training set, transformasi yang sama diterapkan pada test set agar konsistensi data tetap terjaga.

# %%
X_train_transformed = transformer.fit_transform(X_train)
X_test_transformed = transformer.transform(X_test)

# Mendapatkan nama kolom hasil encoding dari OneHotEncoder dan BinaryEncoder
onehot_columns = transformer.transformers_[0][1].get_feature_names_out(['Gear_Type', 'Origin', 'Options'])
binary_columns = transformer.transformers_[1][1].get_feature_names_out(['Type', 'Make', 'Region'])

# Gabungkan dengan nama kolom fitur numerik yang tidak terpengaruh oleh encoding
numerical_columns = [col for col in X.columns if col not in ['Gear_Type', 'Origin', 'Options', 'Type', 'Make', 'Region']]

# Gabungkan semua nama kolom
columns = list(onehot_columns) + list(binary_columns) + numerical_columns

# Buat DataFrame dari hasil transformasi
X_train_transformed_df = pd.DataFrame(X_train_transformed, columns=columns)

# Fungsi untuk menghitung VIF
def calc_vif(X):
    # Menambahkan konstanta untuk menghitung VIF
    X_const = add_constant(X)
    vif = pd.DataFrame()
    vif["variables"] = X_const.columns
    vif["VIF"] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]
    return vif

# Menghitung VIF pada X_train yang sudah ditransformasi
vif_result = calc_vif(X_train_transformed_df)

vif_result
# Out:
#             variables            VIF
# 0               const  917443.393191
# 1    Gear_Type_Manual       1.137434
# 2        Origin_Other       1.765591
# 3        Origin_Saudi       1.819659
# 4   Options_Semi Full       1.350175
# 5    Options_Standard       1.598461
# 6              Type_0       1.237538
# 7              Type_1       1.286496
# 8              Type_2       1.365035
# 9              Type_3       1.129417
# 10             Type_4       1.147089
# 11             Type_5       1.146582
# 12             Type_6       1.084263
# 13             Type_7       1.206045
# 14             Make_0       1.243812
# 15             Make_1       1.550251
# 16             Make_2       1.226628
# 17             Make_3       1.516584
# 18             Make_4       1.572601
# 19             Make_5       1.386307
# 20           Region_0       1.079290
# 21           Region_1       1.350150
# 22           Region_2       1.535708
# 23           Region_3       1.229420
# ...

# %% [markdown]
# ## 5.2 Model Benchmark

# %% [markdown]
# ### 5.2.1 Memilih Model Benchmark

# %% [markdown]
# Terdapat lima model yang dipilih untuk proses modeling, yang terdiri atas model dasar dan ensemble: Linear Regression, Ridge, Lasso, K-Nearest Neighbor, Random Forest, Gradient boost, dan XGBoost.

# %%
# Define algoritma yang digunakan
lr = LinearRegression()
rr = KernelRidge(kernel='polynomial')
ls = Lasso(alpha =0.0005, random_state=randomstate)
knn = KNeighborsRegressor()
rf = RandomForestRegressor(random_state=randomstate)
gb = GradientBoostingRegressor(random_state=randomstate)
xgb = XGBRegressor(random_state=randomstate)

# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_rr = TransformedTargetRegressor(rr, func=np.log, inverse_func=np.exp)
log_ls = TransformedTargetRegressor(ls, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_gb = TransformedTargetRegressor(gb, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)

# %%
# Kandidat algoritma
models = [log_lr, log_rr, log_ls, log_knn, log_rf, log_gb, log_xgb]

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

score_r2 = []
nilai_mean_r2 = []
nilai_std_r2 = []

scaling_models = [log_lr, log_rr, log_ls, log_knn]

# %% [markdown]
# #### 5.2.1.1 *Cross Validation*

# %%
for i in models:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=randomstate)

    if i in scaling_models:
        estimator = Pipeline([
            ('preprocessing', transformer),
            ('scaler', scaler),
            ('model', i)                 
        ])
    else:
        estimator = Pipeline([
            ('preprocessing', transformer),
            ('model', i)
        ])

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
        )

    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())

    # R²
    model_cv_r2 = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='r2', 
        error_score='raise'
        )
    score_r2.append(model_cv_r2)
    nilai_mean_r2.append(model_cv_r2.mean())
    nilai_std_r2.append(model_cv_r2.std())
# Out:
# [-24566.5754273  -26254.20543712 -23303.96649023 -25239.0925934
#  -23699.36100733] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-16975.36242618 -17964.57275186 -15656.14315502 -17949.62920413
#  -15790.55381145] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-0.25577652 -0.26812493 -0.23345254 -0.28016539 -0.2583048 ] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-19286.43985293 -19830.4271741  -18430.90375619 -19392.93742874
#  -19839.94060841] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KernelRidge(kernel='polynomial'))
# [-13098.95007006 -12813.37844572 -12762.16062129 -13032.17332028
# ...

# %%
pd.DataFrame({
    'Model': ['Linear Regression', 'Kernel Ridge', 'Lasso', 'K-Nearest Neighbor', 'RandomForest Regressor', 'Gradient Boost', 'XGBoost Regressor'],
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE': nilai_std_rmse,
    'Mean_MAE': nilai_mean_mae,
    'Std_MAE': nilai_std_mae,
    'Mean_MAPE': nilai_mean_mape,
    'Std_MAPE': nilai_std_mape,
    'Mean_R2': nilai_mean_r2, 
    'Std_R2': nilai_std_r2    
})
# Out:
#                     Model     Mean_RMSE     Std_RMSE      Mean_MAE  \
# 0       Linear Regression -24612.640191  1061.697391 -16867.252270
# 1            Kernel Ridge -19356.129764   514.059456 -12925.494299
# 2                   Lasso -24611.410037  1024.023444 -16862.050108
# 3      K-Nearest Neighbor -19043.502552   685.075324 -12783.335215
# 4  RandomForest Regressor -18480.570243   903.621341 -11925.260088
# 5          Gradient Boost -19182.085716   697.566343 -13046.782565
# 6       XGBoost Regressor -17552.077225   826.047877 -11502.070268
#
#        Std_MAE  Mean_MAPE  Std_MAPE   Mean_R2    Std_R2
# 0  1001.339576  -0.259165  0.015457  0.528546  0.041798
# 1   127.072518  -0.193711  0.006499  0.707762  0.030034
# 2   965.089936  -0.259306  0.015149  0.528670  0.040221
# 3   402.145157  -0.210695  0.007693  0.717352  0.028093
# 4   329.714038  -0.183660  0.007117  0.733885  0.028684
# 5   106.273739  -0.195967  0.006419  0.713194  0.029182
# ...

# %% [markdown]
# Penentuan Model terbaik dilakukan dengan mencari nilai Mean MAE, Mean RMSE, dan Mean MAPE terkecil. Semakin kecil nilai ketiga metriks evaluasi, semakin baik model melakukan prediksi.
#
# Berdasarkan analisis dari nilai Mean RMSE, Mean MAE, dan Mean MAPE, **XGBoost Regressor** adalah model terbaik karena memiliki nilai terkecil di ketiga metrik evaluasi (RMSE, MAE, dan MAPE). Dengan demikian, **XGBoost Regressor** dapat dipertimbangkan sebagai model yang paling baik di antara yang lainnya pada tahap ini.

# %% [markdown]
# #### 5.2.1.2 Evaluasi Model

# %%
models = {
    'XGBoost Regressor': XGBRegressor(random_state=randomstate),
    'Random Forest': RandomForestRegressor(random_state=randomstate)
    }

score_rmse = []
score_mae = []
score_mape = []
score_r2 = []

for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('model', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))
    score_r2.append(model.score(X_test, y_test))

score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape, 'R2 Score': score_r2}, index=models.keys())
score_before_tuning
# Out:
#                            RMSE           MAE      MAPE  R2 Score
# XGBoost Regressor  17469.581488  11505.284274  0.175416  0.752205
# Random Forest      17291.569002  11588.183699  0.183753  0.757230

# %% [markdown]
# - **XGBoost Regressor** sedikit lebih unggul dalam penilaian metrics MAE dan MAPE, yang menunjukkan prediksi lebih akurat dalam hal kesalahan absolut dan persentase kesalahan.
#
# - **Random Forest** sedikit lebih baik dalam penilaian metrics RMSE dan R² Score, menunjukkan bahwa model ini lebih baik dalam hal akurasi deviasi dan menjelaskan variasi dalam data.

# %% [markdown]
# ## 5.3 *Hyperparameter Tuning*

# %% [markdown]
# *Hyperparameter Tuning* dilakukan untuk menemukan kombinasi parameter terbaik yang meningkatkan model. Proses hyperparameter tuning dilakukan berdasarkan dua model; XGBoost Regressor dan Random Forest. Hasil keduanya akan di bandingkan dengan model sebelum proses hyperparameter tuning.

# %% [markdown]
# ### 5.3.1 XGBoost Regressor

# %%
# Kedalaman pohon
max_depth = list(np.arange(3, 11))

# Learning rate
learning_rate = list(np.arange(1, 31)/100)

# Jumlah pohon
n_estimators = list(np.arange(100, 1001))

# Jumlah baris tiap pohon (% dari total baris train set)
subsample = list(np.arange(2, 10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(0, 11)) # Semakin besar nilainya, semakin konservatif/simpel modelnya

# Jumlah feature yang digunakan untuk tiap pohon (% dari total kolom train set)
colsample_bytree = list(np.arange(1, 10)/10)

# Alpha (regularization)
reg_alpha = list(np.logspace(-3, 1, 10)) # Semakin besar nilainya, semakin konservatif/simpel modelnya

# Hyperparam space XGboost
hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=randomstate, verbosity=0)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('model', xgb)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=randomstate)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 50,
    cv = crossval, 
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'r2'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error',
    random_state = randomstate  
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                ['Gear_Type',
#                                                                                 'Origin',
#                                                                                 'Options']),
#                                                                               ('Binary',
#                                                                                BinaryEncoder(),
# ...

# %%
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error', 'mean_test_r2']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6        0.680926      0.026798         0.027800        0.006155
# 23       0.284118      0.011535         0.019926        0.005803
# 2        0.228730      0.005863         0.018166        0.006982
# 4        0.477783      0.006637         0.017455        0.005394
# 19       0.259714      0.010775         0.025472        0.004938
#
#    param_model__subsample param_model__reg_alpha param_model__n_estimators  \
# 6                     0.6               0.059948                       933
# 23                    0.9                0.16681                       319
# 2                     0.8               0.002783                       250
# 4                     0.9                  0.001                       731
# 19                    0.9               0.007743                       140
#
#    param_model__max_depth param_model__learning_rate param_model__gamma  ...  \
# ...

# %%
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -15998.5982464494
# Best_params: {'model__subsample': 0.6, 'model__reg_alpha': 0.05994842503189409, 'model__n_estimators': 933, 'model__max_depth': 5, 'model__learning_rate': 0.02, 'model__gamma': 2, 'model__colsample_bytree': 0.3}

# %%
xgb_tuning = random_xgb.best_estimator_

# Fitting model setelah tuning
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Hitung metrics RMSE, MAE, & MAPE setelah tuning
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = np.mean(np.abs((y_test - y_pred_xgb_tuning) / y_test))
r2_xgb_tuning = xgb_tuning.score(X_test, y_test)

# Simpan hasil dalam DataFrame
score_after_tuning = pd.DataFrame({
    'RMSE': [rmse_xgb_tuning],
    'MAE': [mae_xgb_tuning],
    'MAPE': [mape_xgb_tuning],
    'R2 Score': [r2_xgb_tuning]
}, index=['XGBoost Regressor'])

score_after_tuning
# Out:
#                            RMSE          MAE      MAPE  R2 Score
# XGBoost Regressor  16565.362792  11354.18932  0.180656  0.777193

# %% [markdown]
# ### 5.3.2. Random Forest

# %%
# Kedalaman pohon
max_depth = list(np.arange(3, 21))  # Pilihan kedalaman pohon (lebih dalam -> lebih kompleks)

# Jumlah pohon dalam forest
n_estimators = list(np.arange(100, 1001, 50))  # Lebih banyak pohon -> lebih akurat, tetapi lebih lambat

# Minimum jumlah sampel per daun
min_samples_leaf = list(np.arange(1, 21))  # Untuk menghindari overfitting

# Minimum jumlah sampel untuk split
min_samples_split = list(np.arange(2, 21))  # Semakin besar, semakin konservatif

# Jumlah fitur yang dipilih untuk split di setiap node (% total kolom train set)
max_features = ['sqrt', 'log2', None]  # Bisa berupa sqrt(n_features), log2(n_features), atau seluruh fitur

# Jumlah sampel yang digunakan (% dari total baris train set)
max_samples = list(np.arange(0.5, 1.01, 0.1))  # Untuk membuat forest lebih random (optional)

# Hyperparameter space untuk Random Forest
hyperparam_space_rf = {
    'model__n_estimators': n_estimators,
    'model__max_depth': max_depth,
    'model__min_samples_leaf': min_samples_leaf,
    'model__min_samples_split': min_samples_split,
    'model__max_features': max_features,
    'model__max_samples': max_samples
}

# %%
# Random Forest model
rf = RandomForestRegressor(random_state=randomstate)

# Pipeline
estimator_rf = Pipeline([
    ('preprocessing', transformer),  # Misalnya preprocessing step
    ('model', rf)
])

# Cross-validation
crossval = KFold(n_splits=5, shuffle=True, random_state=randomstate)

# RandomizedSearchCV
random_rf = RandomizedSearchCV(
    estimator=estimator_rf,
    param_distributions=hyperparam_space_rf,
    n_iter=50,
    cv=crossval,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    random_state=randomstate
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_rf.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                ['Gear_Type',
#                                                                                 'Origin',
#                                                                                 'Options']),
#                                                                               ('Binary',
#                                                                                BinaryEncoder(),
# ...

# %%
# Cek skor dan params terbaik
print('Random Forest')
print('Best_score:', random_rf.best_score_)
print('Best_params:', random_rf.best_params_)
# Out:
# Random Forest
# Best_score: -17418.40551495744
# Best_params: {'model__n_estimators': 600, 'model__min_samples_split': 3, 'model__min_samples_leaf': 1, 'model__max_samples': 0.9999999999999999, 'model__max_features': 'sqrt', 'model__max_depth': 14}

# %%
# Pastikan `random_xgb` adalah hasil dari tuning hyperparameter
rf_tuning = random_rf.best_estimator_

# Fitting model setelah tuning
rf_tuning.fit(X_train, y_train)

# Predict test set
y_pred_rf_tuning = rf_tuning.predict(X_test)

# Hitung metrics RMSE, MAE, & MAPE setelah tuning
rmse_rf_tuning = np.sqrt(mean_squared_error(y_test, y_pred_rf_tuning))
mae_rf_tuning = mean_absolute_error(y_test, y_pred_rf_tuning)
mape_rf_tuning = np.mean(np.abs((y_test - y_pred_rf_tuning) / y_test))
r2_rf_tuning = rf_tuning.score(X_test, y_test)

# Simpan hasil dalam DataFrame
rf_score_after_tuning = pd.DataFrame({
    'RMSE': [rmse_rf_tuning],
    'MAE': [mae_rf_tuning],
    'MAPE': [mape_rf_tuning],
    'R2 Score': [r2_rf_tuning]
}, index=['Random Forest'])

# Tampilkan hasil
rf_score_after_tuning
# Out:
#                        RMSE           MAE      MAPE  R2 Score
# Random Forest  17725.596967  12153.672958  0.203464  0.744889

# %% [markdown]
# ## 5.4 Performance Comparison

# %%
# Sebelum hyperparameter tuning
score_before_tuning
# Out:
#                            RMSE           MAE      MAPE  R2 Score
# XGBoost Regressor  17469.581488  11505.284274  0.175416  0.752205
# Random Forest      17291.569002  11588.183699  0.183753  0.757230

# %%
# Setelah hyperparameter tuning
display(score_after_tuning, rf_score_after_tuning)
# Out:
#                            RMSE          MAE      MAPE  R2 Score
# XGBoost Regressor  16565.362792  11354.18932  0.180656  0.777193
#                        RMSE           MAE      MAPE  R2 Score
# Random Forest  17725.596967  12153.672958  0.203464  0.744889

# %% [markdown]
# **XGBoost Regressor**
#
# Hyperparameter tuning pada XGBoost Regressor dinilai efektif dalam meningkatkan kinerja model secara keseluruhan. Adanya penurunan nilai RMSE dan MAE serta peningkata R2 Score dinilai membuat model menjadi lebih akurat, lebih baik dalam menjelaskan variabilitas data, dan memberikan hasil prediksi yang lebih baik.
#
# **Random Forest**
#
# Hyperparameter tuning pada Random Forest memberikan hasil yang kurang optimal dibandingkan XGBoost. Meskipun akurasi dalam hal RMSE dan MAE meningkat, kemampuan model dalam menjelaskan variabilitas data justru menurun.
#
# Berdasarkan hasil evaluasi ini, **XGBoost Regressor** akan digunakan dalam proses analisis residual pada data uji.

# %% [markdown]
# # 6. Analisis Residual
#
# Analisis residual pada model XGBoost adalah cara untuk **mengevaluasi sejauh mana model tersebut dapat memprediksi nilai yang benar**. Residuals adalah selisih antara nilai yang diprediksi oleh model dan nilai aktual (ground truth). Nilai residual yang mendekati nol mengindikasikan model memprediksi dengan baik.
#
# Dalam konteks XGBoost, **analisis residual dapat membantu mengidentifikasi pola atau masalah dalam model, seperti overfitting, underfitting, atau variabel yang belum dimodelkan dengan baik**.
#
# Berikut dataframe mengenai informasi Harga Actual, Harga Prediksi, dan Residual.

# %%
dataframe = pd.DataFrame({
    'Actual': y_test, 
    'Predicted': y_pred_xgb_tuning
})

dataframe['Residual'] = dataframe['Actual'] - dataframe['Predicted']
dataframe.sort_index()
# Out:
#       Actual      Predicted      Residual
# 29     62000   67997.109375  -5997.109375
# 30    141000  135770.234375   5229.765625
# 43     78500   61888.660156  16611.339844
# 44     60000   55043.488281   4956.511719
# 48     45000   63361.050781 -18361.050781
# ...      ...            ...           ...
# 2571   27000   38529.089844 -11529.089844
# 2584   41000   45267.589844  -4267.589844
# 2585   62000   53116.949219   8883.050781
# 2593   56000   54211.769531   1788.230469
# 2597  154000  108135.101562  45864.898438
#
# [520 rows x 3 columns]

# %%
result = saudi.join(dataframe, how='outer')
filtered_result = result[result['Actual'].notna()]
filtered_result
# Out:
#              Type     Region        Make  Gear_Type       Origin    Options  \
# 29          Hilux     Dammam      Toyota     Manual        Saudi  Semi Full
# 30          Yukon     Riyadh         GMC  Automatic  Gulf Arabic   Standard
# 43         Avalon     Jeddah      Toyota  Automatic        Saudi  Semi Full
# 44          Camry     Qassim      Toyota  Automatic  Gulf Arabic   Standard
# 48              S  Al-Medina    Mercedes  Automatic        Saudi       Full
# ...           ...        ...         ...        ...          ...        ...
# 2571  Range Rover     Dammam  Land Rover  Automatic        Saudi       Full
# 2584            3     Jeddah       Mazda  Automatic        Saudi   Standard
# 2585     Sportage     Riyadh         Kia  Automatic        Saudi       Full
# 2593            6     Jeddah       Mazda  Automatic        Saudi  Semi Full
# 2597           RX     Dammam       Lexus  Automatic  Gulf Arabic       Full
#
# ...

# %% [markdown]
# ## 6.1 Plot Aktual VS Prediksi

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x=filtered_result['Actual'], y=filtered_result['Predicted'], color="red", alpha=0.5)
sns.regplot(x=filtered_result['Actual'], y=filtered_result['Predicted'], scatter=False, color="blue", line_kws={"linewidth": 2})

plt.title('Actual vs Prediction Price')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretasi**
#
# 1. Titik-titik data secara umum mengikuti garis diagonal, yang menunjukkan bahwa model mampu memprediksi harga dengan cukup akurat;
#
# 2. Terdapat beberapa titik data yang cukup jauh dari garis diagonal, terutama pada rentang harga yang lebih tinggi. Titik-titik ini mewakili data yang sulit diprediksi oleh model;
#
# 3. Garis regresi (garis biru) menunjukkan tren umum hubungan antara harga aktual dan harga prediksi. Model berhasil menangkap tren kenaikan harga secara umum.

# %% [markdown]
# ## 6.2 Plot Residual vs Prediksi

# %%
plt.scatter(filtered_result['Predicted'], filtered_result['Residual'])
plt.axhline(0, color='red', linestyle='--')
plt.title('Residual vs Predicted')
plt.xlabel('Predicted')
plt.ylabel('Residual')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretasi**
#
# 1. Garis horizontal pada nilai 0 yang berfungsi sebagai acuan. Titik-titik yang berada di atas garis berarti model memprediksi nilai yang terlalu rendah (*underprediction*), sedangkan titik di bawah garis berarti model memprediksi nilai terlalu tinggi (*overprediction*);
#
# 2. Titik-titik menyebar cukup merata di sekitar garis nol, baik di atas maupun di bawahnya. Ini mengindikasikan bahwa model secara umum mampu menangkap tren data dengan baik;
#
# 3. Adanya titik yang jauh dari garis nol, baik di atas maupun di bawah. Ini menunjukkan adanya outlier atau data yang sulit diprediksi oleh model.

# %% [markdown]
# ## 6.3 Plot Histogram dan Uji Statistik Residual

# %%
plt.figure(figsize=(15, 4))
sns.histplot(filtered_result['Residual'], kde=True)
plt.title('Distribusi Residual')
plt.xlabel('Residual')
plt.ylabel('Frekuensi')

plt.show()

# %% [markdown]
# **Uji Shapiro-Wilk**
#
# Uji statistik dengan metode Shapiro-Wilk dilakukan untuk memastikan apakah residual terdistribusi normal atau tidak.

# %%
shapiro(filtered_result['Residual'])

sw_statistic, sw_pvalue = shapiro(filtered_result['Residual'])

if sw_pvalue > 0.05:
    print(f'P-Value: {sw_pvalue}. So, we assume a normal distribution')
else:
    print(f'P-Value: {sw_pvalue}. So, we do not assume a normal distribution')
# Out:
# P-Value: 1.2299677303985213e-14. So, we do not assume a normal distribution

# %% [markdown]
# **Interpretasi**
#
# 1. Kurva distribusi residual pada plot Anda tidak terdistribusi normal dan menunjukkan adanya beberapa titik data dengan nilai residual yang sangat besar (positif).
#
# 2. Distribusi cenderung miring ke kanan (positively skewed), yang mengindikasikan adanya ketidakseimbangan dalam sebaran residual.
#
# 3. Hasil uji statistik menunjukkan nilai p-value yang sangat kecil dan menolak Hipotesis Nol. Hal tersebut menunjukkan bahwa Data residual tidak terdistribusi normal dan menghasilkan prediksi yang tidak akurat.

# %% [markdown]
# Berdasarkan hasil tersebut, dapat diketahui bahwa model tidak terdistribusi normal dan tidak dapat dipercaya namun dapat dipertimbangkan. (ga bisa jadi final decision).

# %% [markdown]
# ## 6.4 Deteksi Outliers

# %%
plt.figure(figsize=(15,4))
sns.boxplot(x=filtered_result['Residual'], color='lightblue')
plt.title('Boxplot Residual')
plt.xlabel('Residual')
plt.grid()
plt.show()

# %%
# Mendapatkan nilai kuartil dan limit
q1 = filtered_result['Residual'].quantile(0.25)
q3 = filtered_result['Residual'].quantile(0.75)
iqr = q3 - q1
limit = iqr * 1.5

lowerbound = q1 - limit
upperbound = q3 + limit

print('IQR =', iqr)
print('Batas Bawah =', lowerbound)
print('Batas Atas =', upperbound)
# Out:
# IQR = 14794.05078125
# Batas Bawah = -30491.794921875
# Batas Atas = 28684.408203125

# %% [markdown]
# **Insight**
#
# 1. Bentuk boxplot yang sedikit lebih panjang ke arah kanan mengindikasikan bahwa model cenderung sedikit *overpredicting* (memperkirakan terlalu tinggi) untuk sebagian data;
#
# 2. Nilai IQR sebesar **14794,05 SAR** menunjukkan bahwa 50% dari data residual berada dalam rentang sebesar **14794,05 SAR** satuan;
#
# 3. Batas Bawah (*Lower Bound*) sebesar **-30491,79 SAR**. Data di bawah batas bawah ini dianggap sebagai outlier dan menunjukkan ada prediksi model yang jauh lebih rendah dari nilai aktualnya;
#
# 4. Batas atas (*Upper Bound*) sebesar **28684,41 SAR**. Data di atas batas atas ini juga dianggap sebagai outlier. Ini menunjukkan adanya beberapa prediksi model yang jauh lebih tinggi dari nilai aktualnya.
#
# Adapun data outlier terlampir pada tabel berikut:

# %%
extreme_values = filtered_result[(filtered_result['Residual'] > 28684) | (filtered_result['Residual'] < -30491)].sort_values(by='Residual', ascending=False)
display(extreme_values.head(), extreme_values.tail())
# Out:
#              Type     Region       Make  Gear_Type       Origin Options  Year  \
# 767   Flying Spur     Dammam    Bentley  Automatic        Saudi    Full  2010
# 1014            X     Riyadh        BMW  Automatic  Gulf Arabic    Full  2015
# 1765        Prado     Jubail     Toyota  Automatic        Saudi    Full  2015
# 2023     Suburban    Al-Baha  Chevrolet  Automatic        Saudi    Full  2015
# 2504         F150  Al-Medina       Ford  Automatic        Saudi    Full  2017
#
#       Engine_Size  Mileage   Price    Actual      Predicted      Residual
# 767           5.0    58000  175000  175000.0   95103.109375  79896.890625
# 1014          1.6    72000  170000  170000.0   94546.789062  75453.210938
# 1765          1.6    55000  130000  130000.0   56085.093750  73914.906250
# 2023          5.3    70000  160000  160000.0   99917.414062  60082.585938
# 2504          2.8    28000  175000  175000.0  116173.335938  58826.664062
# ...

# %%
# Untuk mengetahui proporsi data ekstrim terhadap data test dapat dilihat pada syntax berikut

# Menghitung jumlah data ekstrem
extreme_values_count = len(extreme_values)

# Menghitung proporsi terhadap y_test
proportion = extreme_values_count / len(y_test)
proportion

display(extreme_values_count, proportion)
# Out:
# 38
# 0.07307692307692308

# %% [markdown]
# ## 6.5 QQ Plot Residual

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# QQ Plot Residual
sm.qqplot(filtered_result['Residual'], line='s', ax=axes[0])
axes[0].set_title('QQ Plot of Residuals')

# QQ Plot Predicted
sm.qqplot(filtered_result['Predicted'], line='s', ax=axes[1])
axes[1].set_title('QQ Plot of Predicted Values')

# Menampilkan plot
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# **Interpretasi**
#
# 1. Titik-titik pada QQ Plot residual menunjukkan penyimpangan yang cukup signifikan dari garis lurus, terutama pada ekor distribusi. Ini mengindikasikan bahwa distribusi residual tidak normal;
#
# 2. Titik-titik pada QQ Plot nilai prediksi menunjukkan penyimpangan dari garis lurus, terutama pada ekor distribusi. Ini menunjukkan bahwa distribusi nilai prediksi juga tidak sepenuhnya normal;

# %% [markdown]
# ## 6.6 Feature Importance

# %%
xgb_model = xgb_tuning.named_steps['model']
feature_names = transformer.get_feature_names_out()
feature_imp = pd.DataFrame({"Features": feature_names, "Value": xgb_model.feature_importances_}).sort_values("Value", ascending=False)

# Plot bar chart untuk Top 10 Fitur yang Paling Penting
plt.figure(figsize=(8, 6))
sns.barplot(data=feature_imp.head(10), x="Value", y="Features", color="lightblue")
plt.title("Top 10 Feature Importance (XGBoost)", fontsize=16)
plt.xlabel("Feature Importance", fontsize=14)
plt.ylabel("Features", fontsize=14)
plt.show()

# %% [markdown]
# **Interpretasi**
#
# Berdasarkan Gambar di atas, tiga fitur yang paling berpengaruh terhadap Harga Mobil bekas yaitu Engine_Size, Options (Standard), dan tahun produksi mobil.

# %% [markdown]
# ## 6.7 Analisis SHAP

# %%
# Model dengan parameter terbaik
xgb_model = XGBRegressor(
    subsample=0.7,
    reg_alpha=1.2915496650148828,
    n_estimators=379,
    max_depth=6,
    learning_rate=0.11,
    gamma=10,
    colsample_bytree=0.5,
    random_state=42
)
xgb_model.fit(X_train_transformed, y_train)

# Membuat objek SHAP explainer
explainer = shap.Explainer(xgb_model, X_train_transformed_df)

# Menghitung nilai SHAP
shap_values = explainer(X_train_transformed_df)
# Out:
#  98%|===================| 2039/2078 [00:39<00:00]

# %%
shap.summary_plot(shap_values, X_train_transformed)

# %% [markdown]
# **Interpretasi**
#
# Urutan fitur yang dihasilkan dari analisis menggunakan metode SHAP berbeda dengan analisis feature importance sebelumnya. Tiga fitur yang paling berpengaruh terhadap harga mobil bekas yang dijual di Syarah.com menurut metode ini, yaitu:
#
# 1. **Engine_Size**: Fitur ini memiliki pengaruh yang cukup besar terhadap prediksi. Semakin besar ukuran mesin, semakin tinggi prediksi harga;
# 2. **Year**: Kendaraan yang lebih baru cenderung memiliki prediksi harga yang lebih tinggi;
# 3. **Mileage**: Fitur ini memiliki pengaruh negatif terhadap prediksi. Semakin tinggi jarak tempuh, semakin rendah prediksi harganya.

# %% [markdown]
# # 7. Kesimpulan dan Rekomendasi

# %% [markdown]
# ## 7.1 Kesimpulan

# %% [markdown]
# Kesimpulan dari hasil analisa prediksi Harga Mobil Bekas di Arab Saudi berdasarkan website Syarah.com yaitu:
#
# 1. Analisis prediksi harga menggunakan model XGBoost menunjukkan hasil yang cukup baik, dengan model mampu menangkap tren utama dari data. Namun, masih terdapat outlier yang memengaruhi performa model dan perlu penanganan lebih lanjut;
#
# 2. Visualisasi menggunakan QQ Plot untuk residual dan nilai prediksi menunjukkan bahwa distribusi residual tidak sepenuhnya normal. Hal ini dapat memengaruhi validitas uji statistik tertentu dan menunjukkan adanya bias yang mungkin perlu diperbaiki;
#
# 3. Berdasarkan analisis Feature Importance dan Metode SHAP, fitur Engine_Size adalah yang paling berpengaruh terhadap target prediksi (Price). Selain itu, fitur lain seperti Year, Mileage, dan Options (Standard) juga memiliki kontribusi terhadap harga mobil bekas.
#
# Meskipun model XGBoost memberikan hasil yang cukup baik untuk menangkap tren secara umum, distribusi residual yang tidak normal menunjukkan bahwa model ini belum sepenuhnya optimal untuk menjadi dasar keputusan akhir (final decision). Diperlukan langkah-langkah tambahan seperti penanganan outlier dan eksplorasi model alternatif untuk meningkatkan akurasi prediksi serta validitas analisis.

# %% [markdown]
# ## 7.2 Rekomendasi

# %% [markdown]
# **Rekomendasi untuk Data**
#
# 1. Penambahan fitur baru seperti usia mobil, harga per kilometer, kategori mobil, lokasi spesifik, dan fitur lainnya yang dapat memberikan wawasan lebih dalam;
#
# 2. Menambahkan data eksternal seperti rata-rata harga mobil bekas berdasarkan merk (Make) atau lokasi (Region) yang dapat meningkatkan akurasi prediksi harga mobil bekas;
#
# 3. Menambahkan data makroekonomi seperti harga bahan bakar atau inflasi, yang mungkin berhubungan dengan fluktuasi harga jual mobil bekas.
#
# **Rekomendasi untuk Model**
#
# 1. Melakukan modeling terpisah untuk fitur-fitur seperti Type atau Make untuk menganalisis pengaruhnya terhadap harga mobil;
#
# 2. Identifikasi dan menangani outlier pada fitur dengan menggunakan metode statistik seperti z-score atau IQR, atau dengan melakukan transformasi data (misalnya log-transformation) untuk mengurangi pengaruh outlier yang dapat mengganggu akurasi model;
#
# 3. Lakukan segmentasi data berdasarkan jenis mobil (Type), merek (Make), atau ukuran mesin (Engine_Size) untuk analisis yang lebih spesifik dan memahami trean yang berbeda di setiap segmen;
#
# 4. Explorasi Model Alternatif untuk melihat apakah mereka memberikan hasil yang lebih baik daripada XGBoost. Selain itu, lakukan hyperparameter tuning yang lebih ekstensif untuk model untuk optimalisasi kinerja dan mencapai prediksi yang lebih akurat.
#
# **Rekomendasi untuk Bisnis**
#
# 1. Model ini belum sepenuhnya optimal untuk menjadi dasar keputusan akhir (final decision). Model dapat digunakan sebagai alat pendukung untuk memberikan rekomendasi harga yang masuk akal kepada penjual, sambil mempertimbangkan faktor eksternal lain yang mungkin tidak terdata;
#
# 2. Evaluasi performa model secara berkala, terutama jika terdapat perubahan besar di pasar;
#
# 3. Implementasikan fitur dalam aplikasi yang memungkinkan pengguna melihat alasan di balik prediksi harga (misalnya, visualisasi SHAP), sehingga penjual dan pembeli lebih memahami bagaimana harga ditentukan;
#
# 4. Terapkan strategi negosiasi harga otomatis berdasarkan hasil model, tetapi dengan batasan tertentu untuk menjaga agar harga tetap memenuhi ekspektasi penjual dan menguntungkan perusahaan.
